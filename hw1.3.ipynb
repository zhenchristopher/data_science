# %% [markdown]
# <div class="alert alert-info">
# good job! 45/40
# </div>

# %% [markdown]
# ## Attributions
#
# **Chris**: Bulk of problems (a)-(d)
#
# **Emily**: Part (d) and edits to problems (a)-(c); documentation
#
# **Naveen**: Section headers
#
# ## Python Setup
#
# Import and initiate modules.

# %%
# Imports

import numpy as np
import pandas as pd

import bokeh.io
import bokeh.plotting

from IPython.display import display # Compatibility fix

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="47786a76-716d-4f24-8171-87730a593731">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Part (a): Reading data on microtubule catastrophe (Gardner, Zanic, et al.)
#
# First let's load the data file to visualize what we're working with.

# %%
# Load data file stored in /data folder
df = pd.read_csv('../data/gardner_et_al_2011_time_to_catastrophe_dic.csv', comment='#')

df.head()
# Out:
#    time to catastrophe with labeled tubulin (s)  \
# 0                                           470
# 1                                          1415
# 2                                           130
# 3                                           280
# 4                                           550
#
#    time to catastrophe with unlabeled tubulin (s)
# 0                                           355.0
# 1                                           425.0
# 2                                           540.0
# 3                                           265.0
# 4                                          1815.0

# %% [markdown]
# ## Part (b): Tidying the the data
#
# We can see that this data isn't tidy because each row is not a single observation. For example, it doesn't make sense to include the two observed times of 470s and 355s in the first line because they are not observations from the same experimental setup - one is from a labeled experiment and the other is unlabeled.
#
# Instead, we should have each observational unit in their own separate table, which we can accomplish by creating a new dataframe for both labeled and unlabeled tubulin.

# %%
# Create new dataframes
labeled_df = (pd.DataFrame(data=df['time to catastrophe with labeled tubulin (s)'],
                           columns=['time to catastrophe with labeled tubulin (s)']))

unlabeled_df = (pd.DataFrame(data=df['time to catastrophe with unlabeled tubulin (s)'],
                           columns=['time to catastrophe with unlabeled tubulin (s)']))

# Remove the extra rows of NaN in the unlabeled dataframe, since there are fewer 
# trials of unlabeled than labeled
unlabeled_df = unlabeled_df.dropna(axis=0, how='any')

# Display the two new dataframes
display(labeled_df)
display(unlabeled_df)
# Out:
#      time to catastrophe with labeled tubulin (s)
# 0                                             470
# 1                                            1415
# 2                                             130
# 3                                             280
# 4                                             550
# 5                                              65
# 6                                             330
# 7                                             325
# 8                                             340
# 9                                              95
# 10                                             55
# 11                                            360
# 12                                            220
# 13                                            225
# 14                                            320
# 15                                             60
# 16                                            210
# 17                                            155
# 18                                            875
# 19                                           1000
# 20                                            475
# 21                                            295
# 22                                            245
# 23                                            415
# 24                                            305
# 25                                            320
# 26                                            370
# 27                                            505
# 28                                           1180
# 29                                            440
# ..                                            ...
# 181                                           350
# 182                                           155
# 183                                          1095
# 184                                           465
# 185                                           215
# 186                                           365
# 187                                           605
# 188                                           520
# 189                                           280
# 190                                           610
# 191                                           765
# 192                                           290
# 193                                           240
# 194                                           180
# 195                                           225
# 196                                          1030
# 197                                           155
# 198                                           215
# 199                                           705
# 200                                           285
# 201                                           135
# 202                                           465
# 203                                            80
# 204                                           370
# 205                                           480
# 206                                           195
# 207                                           705
# 208                                           300
# 209                                           605
# 210                                           600
#
# [211 rows x 1 columns]
#     time to catastrophe with unlabeled tubulin (s)
# 0                                            355.0
# 1                                            425.0
# 2                                            540.0
# 3                                            265.0
# 4                                           1815.0
# 5                                            160.0
# 6                                            370.0
# 7                                            460.0
# 8                                            190.0
# 9                                            130.0
# 10                                           460.0
# 11                                           140.0
# 12                                           295.0
# 13                                           445.0
# 14                                           210.0
# 15                                           360.0
# 16                                           575.0
# 17                                           320.0
# 18                                           180.0
# 19                                           180.0
# 20                                           615.0
# 21                                           145.0
# 22                                           870.0
# 23                                           420.0
# 24                                           460.0
# 25                                           265.0
# 26                                           150.0
# 27                                           770.0
# 28                                            75.0
# 29                                            40.0
# ..                                             ...
# 65                                           160.0
# 66                                           170.0
# 67                                           700.0
# 68                                           695.0
# 69                                           415.0
# 70                                           305.0
# 71                                           145.0
# 72                                           350.0
# 73                                           640.0
# 74                                           165.0
# 75                                           370.0
# 76                                           525.0
# 77                                           950.0
# 78                                           125.0
# 79                                          1255.0
# 80                                           155.0
# 81                                           735.0
# 82                                           215.0
# 83                                           195.0
# 84                                           660.0
# 85                                            80.0
# 86                                           235.0
# 87                                           500.0
# 88                                          1145.0
# 89                                           540.0
# 90                                           180.0
# 91                                           145.0
# 92                                           745.0
# 93                                           390.0
# 94                                          1410.0
#
# [95 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-info">
# good 15/15<br>
# Watch out for unnecessary code (renaming the columns with the same name and extra parentheses when you create the individual datraframes).
# </div>

# %% [markdown]
# ## Part (c): Plotting cumulative distributions
#
# Now that our data is tidy, we can do a calculation of the empirical cumulative distribution function (ECDF). It is defined as ECDF(x) = fraction of data points ≤ x.

# %%
def ecdf_vals(data):
    """
    Compute the (x, y) value pairs to plot an ECDF function from a numpy array of pandas series
    
    Parameters
    ----------
    data : 1D numpy array/pandas series
           data used to plot the ECDF
           
    Returns
    -------
    output: np.array(data.size, 2)
            returns and np array where the first column is the data-value
            and the second column is the cumulative distribution at that point
    
    """
    
    # Convert to np.array if data is a dataframe
    if isinstance(data, pd.DataFrame):
        data = data.as_matrix()
        data.resize(data.size)
    
    # Initialize x-y values
    xy = np.zeros([2, data.size])
    
    # Initialize fraction of data points <= x as y
    xy[1] = np.linspace(0, 1, data.size+1)[1:]
    
    # Sort data points and add to x
    xy[0] = np.sort(data)
    
    return xy

# %% [markdown]
# <div class="alert alert-info">
# Your function is not exactly correct. The first y-value should be `1/len(data)`, not 0, since that value itself counts. It is also unnecessary to pack the x,y values into one array to then unpack them below.
# </div>

# %% [markdown]
# Now, we can write a function to visualize the data by plotting the ECDF function.

# %%
# Create figure
p = bokeh.plotting.figure(plot_height=300,
                          plot_width=500,
                          x_axis_label='x',
                          y_axis_label='y',
                          title = "ECDF of Time to Catastrophe for Labeled and Unlabeled Tubulins")

# Find ECDF x-y values
ecdf_labeled = ecdf_vals(labeled_df)
ecdf_unlabeled = ecdf_vals(unlabeled_df)

# Plot both labeled and unlabeled ECDF points
p.circle(ecdf_labeled[0], ecdf_labeled[1],
         color='dodgerblue', legend='Labeled')
p.circle(ecdf_unlabeled[0], ecdf_unlabeled[1],
         color='tomato', legend='Unlabeled')

# Changing some graph features
p.xaxis.axis_label = "Time to Catastrophe (s)"
p.yaxis.axis_label = "ECDF"
p.legend.location = 'bottom_right'

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8ba8df8f-27f4-4659-8d04-85f7ccc0de6f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8ba8df8f-27f4-4659-8d04-85f7ccc0de6f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8ba8df8f-27f4-4659-8d04-85f7ccc0de6f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8ba8df8f-27f4-4659-8d04-85f7ccc0de6f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3556c17f-2caf-4ac1-b641-aca486ca0b83":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"83e10651-cc4a-43d7-86a5-ac4404b86211","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"34adf276-b94c-42ba-97a2-db178ba96742","subtype":"Figure","type":"Plot"}},"id":"b1b6558c-308d-4171-abef-54f225aed1f5","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"83e10651-cc4a-43d7-86a5-ac4404b86211","type":"BoxAnnotation"},"plot":{"id":"34adf276-b94c-42ba-97a2-db178ba96742","subtype":"Figure","type":"Plot"}},"id":"2ac177ef-ee12-4b11-9000-03f0db5e2d2c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"34adf276-b94c-42ba-97a2-db178ba96742","subtype":"Figure","type":"Plot"}},"id":"ef1d1ce1-a3e1-412c-acf8-595c6ed9cc6c","type":"SaveTool"},{"attributes":{"plot":{"id":"34adf276-b94c-42ba-97a2-db178ba96742","subtype":"Figure","type":"Plot"}},"id":"a838aa98-57b4-4b3e-9a18-5714e773f16f","type":"ResetTool"},{"attributes":{"plot":{"id":"34adf276-b94c-42ba-97a2-db178ba96742","subtype":"Figure","type":"Plot"}},"id":"22fe1f7e-57e7-4277-89a1-e0a2c295cbba","type":"HelpTool"},{"attributes":{"items":[{"id":"d9b32980-02a0-4e6d-a9b8-5a1bcd595837","type":"LegendItem"},{"id":"15dab398-92eb-453e-a949-2c8f54b9ee2e","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"34adf276-b94c-42ba-97a2-db178ba96742","subtype":"Figure","type":"Plot"}},"id":"d8f79a94-1b0d-4c0c-b354-fb500ef443ed","type":"Legend"},{"attributes":{"label":{"value":"Labeled"},"renderers":[{"id":"984687e6-ec21-4522-b060-425a2a7b3bef","type":"GlyphRenderer"}]},"id":"d9b32980-02a0-4e6d-a9b8-5a1bcd595837","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e503538-4965-40ab-89fa-be957eadbf86","type":"Circle"},{"attributes":{"fill_color":{"value":"tomato"},"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1de346b0-e5dd-4191-af89-6ac3484efc85","type":"Circle"},{"attributes":{"label":{"value":"Unlabeled"},"renderers":[{"id":"d7125885-4fc7-4c91-9727-86790fb4d10c","type":"GlyphRenderer"}]},"id":"15dab398-92eb-453e-a949-2c8f54b9ee2e","type":"LegendItem"},{"attributes":{"data_source":{"id":"57bf8e76-34c1-4a35-810f-37f7fc6a57d7","type":"ColumnDataSource"},"glyph":{"id":"1de346b0-e5dd-4191-af89-6ac3484efc85","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"6e503538-4965-40ab-89fa-be957eadbf86","type":"Circle"},"selection_glyph":null},"id":"d7125885-4fc7-4c91-9727-86790fb4d10c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"34adf276-b94c-42ba-97a2-db178ba96742","subtype":"Figure","type":"Plot"}},"id":"6e9661ce-87fa-458a-b73c-f141cc7e23e1","type":"PanTool"},{"attributes":{"data_source":{"id":"fcea5746-efe4-4606-addb-918e3e40a8d6","type":"ColumnDataSource"},"glyph":{"id":"0aef9ff3-e147-4d41-8422-6a98b546b0d6","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"235183b8-eb6c-4791-bf11-222f1dd1ca06","type":"Circle"},"selection_glyph":null},"id":"984687e6-ec21-4522-b060-425a2a7b3bef","type":"GlyphRenderer"},{"attributes":{},"id":"8299fa24-a1c6-43d2-873e-84448664c65a","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[95]},"y":{"__ndarray__":"...","dtype":"float64","shape":[95]}}},"id":"57bf8e76-34c1-4a35-810f-37f7fc6a57d7","type":"ColumnDataSource"},{"attributes":{"axis_label":"Time to Catastrophe (s)","formatter":{"id":"8299fa24-a1c6-43d2-873e-84448664c65a","type":"BasicTickFormatter"},"plot":{"id":"34adf276-b94c-42ba-97a2-db178ba96742","subtype":"Figure","type":"Plot"},"ticker":{"id":"c371 ...

# %% [markdown]
# <div class="alert alert-info">
# 25/25
# </div>

# %% [markdown]
# ## Part (d): Plotting
#
# Now we'll try and plot the ECDFs using a line plot instead of using points/scatterplot. To do this, we first create a function plot_ecdf_formal that prepares x and y values for a line plot:

# %%
def plot_ecdf_formal(data):
    """
    Compute the (x, y) value pairs to plot an ECDF function from a numpy array of pandas series
    for plotting a line plot
    
    Parameters
    ----------
    data : 1D numpy array/pandas series
           data used to plot the ECDF
           
    Returns
    -------
    output: np.array(data.size, 2)
            returns and np array where the first column is the data-value
            and the second column is the cumulative distribution at that point
    
    """
    
    # Convert to np.arry if data is a dataframe
    if isinstance(data, pd.DataFrame):
        data = data.as_matrix()
        data.resize(data.size)
    
    # Initialize x-y values
    xy = np.zeros([2, 2*data.size - 1])
    
    # Initialize fraction of data points <= x as y
    y = np.zeros([2, data.size-1])
    
    # Copy all values but the last freq value to another column
    y[0] = y[1] = np.linspace(0, 1, data.size+1)[1:-1]
    
    # Append the two columns by flattening
    xy[1,:-1] = (y.T).flatten()
    
    # Set last value
    xy[1,-1] = 1
    
    # Since we are sorting the data anyways, we can just sort it this
    # time to get it in order without much performance loss
    x = np.sort(data)
    x = np.append(x, x[1:])
    xy[0] = np.sort(x)
    
    return xy

# %% [markdown]
# Next, we use the function above to create a Bokeh figure:

# %%
# Create figure
p = bokeh.plotting.figure(plot_height=300,
                          plot_width=500,
                          x_axis_label='x',
                          y_axis_label='y',
                          title = "Formal ECDF of Time to Catastrophe for Labeled/Unlabeled Tubulins")

# Find ECDF x-y values
form_ecdf_labeled = plot_ecdf_formal(labeled_df)
form_ecdf_unlabeled = plot_ecdf_formal(unlabeled_df)

# Plot both labeled and unlabeled ECDF points
p.line(form_ecdf_labeled[0], form_ecdf_labeled[1],
         color='dodgerblue', legend='Labeled')
p.line(form_ecdf_unlabeled[0], form_ecdf_unlabeled[1],
         color='tomato', legend='Unlabeled')

# Changing some graph features
p.xaxis.axis_label = "Time to Catastrophe (s)"
p.yaxis.axis_label = "ECDF"
p.legend.location = 'bottom_right'

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="357bdb31-0bba-4b67-ba33-905f4c404340"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("357bdb31-0bba-4b67-ba33-905f4c404340").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("357bdb31-0bba-4b67-ba33-905f4c404340");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '357bdb31-0bba-4b67-ba33-905f4c404340' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0dc7c8d3-a1b4-4ecf-9907-dc5938a9778c":{"roots":{"references":[{"attributes":{"callback":null},"id":"681bc86c-7e02-403d-b259-a1d72e7f3fa9","type":"DataRange1d"},{"attributes":{"axis_label":"ECDF","formatter":{"id":"27c8f62a-d1f3-42d2-9a1a-0dbff96ac92e","type":"BasicTickFormatter"},"plot":{"id":"07ea0779-5334-471c-9b88-69c765b1c7fd","subtype":"Figure","type":"Plot"},"ticker":{"id":"4faae870-3a97-4633-b8a4-d1078940bc54","type":"BasicTicker"}},"id":"65f985b2-a32a-403c-9264-beaf3dfb0c06","type":"LinearAxis"},{"attributes":{},"id":"4faae870-3a97-4633-b8a4-d1078940bc54","type":"BasicTicker"},{"attributes":{"plot":{"id":"07ea0779-5334-471c-9b88-69c765b1c7fd","subtype":"Figure","type":"Plot"},"ticker":{"id":"ada66353-f081-43df-913a-d78210d71eb8","type":"BasicTicker"}},"id":"d07c1ec2-0352-47af-95a6-696a4c500b45","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[189]},"y":{"__ndarray__":"...","dtype":"float64","shape":[189]}}},"id":"0d270db9-3558-48b3-b277-f94dd4454f8b","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1c87cd9-2971-472a-b5fb-eae85ddfe64a","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[421]},"y":{"__ndarray__":"...","dtype":"float64","shape":[421]}}},"id":"c82d7071-9acf-4c18-8cc2-63ab1feda331","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"281d7538-e56d-47d5-bb2c-917f151e4287","type":"LinearAxis"}],"left":[{"id":"65f985b2-a32a-403c-9264-beaf3dfb0c06","type":"LinearAxis"}],"plot_height":300,"plot_width":500,"renderers":[{"id":"281d7538-e56d-47d5-bb2c-917f151e4287","type":"LinearAxis"},{"id":"d07c1ec2-0352-47af-95a6-696a4c500b45","type":"Grid"},{"id":"65f985b2-a32a-403c-9264-beaf3dfb0c06","type":"LinearAxis"},{"id":"a345ba55-99a4-4028-864e-cb6c0e22fb23","type":"Grid"},{"id":"cc7ad4c2-bb4c-4d4e-b4a4-fb47c9a5b7ea","type":"BoxAnnotation"},{"id":"e6a2a895-da53-4866-b3c8-090ad0cac928","type":"Legend"},{"id":"7a21c4f0-51e4-4b8d-a885-fb1c784826dd","type":"GlyphRenderer"},{"id":"fbb38fd1-3f7f-4f44-a004-57e2887bdba3","type":"GlyphRenderer"}],"title":{"id":"813bd0d8-c772-4131-87cf-056f84e04567","type":"Title"},"tool_events":{"id":"a3e815ca-fb74-4be8-a1b9-401f448679f8","type":"ToolEvents"},"toolbar":{"id":"456a43ef-7e83-4a08-a5ed-f9d8ae03b196","type":"Toolbar"},"x_range":{"id":"681bc86c-7e02-403d-b259-a1d72e7f3fa9","type":"DataRange1d"},"y_range":{"id":"b20c8459-a8cb-4897-af98-edb1bda26877","type":"DataRange1d"}},"id":"07ea0779-5334-471c-9b88-69c765b1c7fd","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"c82d7071-9acf-4c18-8cc2-63ab1feda331","type":"ColumnDataSource"},"glyph":{"id":"6c0201c3-9cb0-4364-9747-9662b7abda2e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"db01ccc9-7742-4f8d-b853-60892305ae44","type":"Line"},"selection_glyph":null},"id":"7a21c4f0-51e4-4b8d-a885-fb1c784826dd","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"07ea0779-5334-471c-9b88-69c765b1c7fd","subtype":"Figure","type":"Plot"}},"id":"07429abc-a6d8-43c3-aa38-85a5859a1e30","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"cc7ad4c2-bb4c-4d4e-b4a4-fb47c9a5b7ea","type":"BoxAnnotation"},"plot":{"id":"07ea0779-5334-471c-9b88-69c765b1c7fd","subtype":"Figure","type":"Plot"}},"id":"4a9b9def-c4e7-4239-80c9-3c37adbd4146","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"Formal ECDF of Time to Catastrophe for Labeled/Unlabeled Tubulins"},"id":"813bd0d8-c772-4131-87cf-056f84e04567","type":"Title"},{"attributes":{"line_color":{"value":"dodgerblue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c0201c3-9cb0-4364-9747-9662b7abda2e","type":"Line"},{"attributes":{},"id":"a3e815ca-fb74-4be8-a1b9-401f448679f8","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8ab3ad98 ...

# %% [markdown]
# <div class="alert alert-info">
# Same comment here, but nice otherwise 5/5
#
# </div>
