# %% [markdown]
# # Attributions
#
# **Chris:** Bulk of problem
#
# **Emily:** Added a few lines of explanation
#
# **Naveen:** Looked over final answer

# %%
import glob
import os

import numpy as np
import pandas as pd
import scipy.signal
import scipy

# Image processing tools
import skimage
import skimage.io

# MCMC tools
import pymc3 as pm
import theano.tensor as tt
import theano

import bebi103

import bokeh
bokeh.io.output_notebook()

import ipywidgets
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="029bc709-3206-4ca9-952f-4726b0d9ea44">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Let's load in the image data and take a look at the number of frames.

# %%
# Load in TIFF stack
fname = '../data/goehring_FRAP_data/PH_138_A.tif'
ic = skimage.io.ImageCollection(fname, conserve_memory=False)[0]

# How long is it?
print('There are {0:d} frames.'.format(len(ic)))
# Out:
# There are 149 frames.

# %% [markdown]
# Taking constants from the README file:

# %%
# Image resolution in um/px
RES = .138

# Bleach time (first frame)
FIRST_BLEACH = 21

# Time interval between frames
T_INTERVAL = 0.188

# %% [markdown]
# Let's load the images and use the interactive clicking to locate the vertices of the ROIs. We have recorded them after clicking, for our convenience, and cropped the images.

# %%
# Time intervals of each TIFF stack
times = np.linspace(0, (len(ic) - 1) * T_INTERVAL, len(ic)) - (FIRST_BLEACH - 1) * T_INTERVAL

# Load images
data_loc = '../data/goehring_FRAP_data'
im_glob = os.path.join(data_loc, '*.tif')
im_list = glob.glob(im_glob)

imgs = skimage.io.ImageCollection(im_list, conserve_memory=False)

# for img in imgs:
#     bokeh.io.show(bebi103.viz.imshow(img[20], flip=False, record_clicks=True))

# Vertices from photobleached squares

roiVerts = [np.array([[16.7912, 10.7605], [13.9775, 59.7350], [66.6332, 60.1005], [68.6430, 11.8569]]),
            np.array([[45.3298, 78.0776], [96.3777, 76.6156], [96.3777, 25.8138], [46.5356, 27.2757]]),
            np.array([[50.5551, 66.4507], [99.5933, 63.8923], [97.9855, 15.2833], [50.1532, 17.1107]]),
            np.array([[58.9961, 97.9506], [103.6128, 97.9506], [108.8382, 50.0726], [61.8098, 49.7071]]),
            np.array([[19.6048, 111.1764], [69.4469, 108.9836], [72.6625, 60.0091], [22.4185, 59.6436]]),
            np.array([[15.1834, 104.6663], [64.6235, 105.3973], [67.8391, 56.0573], [17.5951, 54.9609]]),
            np.array([[15.9873, 112.0445], [67.0352, 110.9480], [70.6528, 64.8974], [20.8107, 60.5116]]),
            np.array([[21.2127, 104.0724], [70.6528, 104.0724], [74.6723, 57.6563], [25.2322, 56.5599]])]

roi = [bebi103.image.verts_to_roi(verts, *imgs[0][0].shape)[1] for verts in roiVerts]

# Now get the cropped images based on the ROI
cropped = []

for index, img in enumerate(imgs):
    cropped.append(np.array([frame[roi[index]] for frame in img]))

# %% [markdown]
# We'll now calculate the average fluorescence and normalize it for comparison.

# %%
# Now find the average fluorescence of each frame of each TIFF stack
avg_fluor = [np.mean(image, axis=(1, 2)) for image in cropped]

# Normalize each stack according to mean fluorescence before bleaching
norm_fluor = [stack / np.mean(stack[:FIRST_BLEACH-1]) for stack in avg_fluor]

# Plot our normalized fluorescences
plots = []
names = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
    
for index, stack in enumerate(norm_fluor):
    p = bokeh.plotting.figure(plot_width=500,
                              plot_height=400,
                              x_axis_label='Time (s)',
                              y_axis_label='Fluorescence (AU)',
                              title=names[index])
    p.circle(times, stack)
    plots.append(p)
    
bokeh.io.show(bokeh.layouts.gridplot(plots, ncols=2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="68b81cbc-b278-48dc-85a3-c12c9956c99b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("68b81cbc-b278-48dc-85a3-c12c9956c99b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("68b81cbc-b278-48dc-85a3-c12c9956c99b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '68b81cbc-b278-48dc-85a3-c12c9956c99b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0f5b4cbf-89f8-4cb6-a920-1d9d26847e1a":{"roots":{"references":[{"attributes":{"children":[{"id":"3f6ab214-062d-4ede-8efb-d40a2a1dc20c","subtype":"Figure","type":"Plot"},{"id":"88a7323c-083c-4946-9931-110e6c9e5c13","subtype":"Figure","type":"Plot"}]},"id":"0f9d0911-7ae4-49d5-85a9-5ff333a8ac23","type":"Row"},{"attributes":{},"id":"1f54bfe3-b839-4071-89cb-27f1205579c5","type":"BasicTickFormatter"},{"attributes":{},"id":"ac97dee7-e9e2-4e5f-a146-55617b36167a","type":"HelpTool"},{"attributes":{"source":{"id":"110fac54-ec25-4221-a761-f665f918c396","type":"ColumnDataSource"}},"id":"78f2da16-c32f-41c0-ad07-0ebc8bb28c18","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3a2292d2-1bbf-4a2a-a805-edff1617a2ca","type":"Circle"},{"attributes":{},"id":"1663ab90-8636-4a39-8092-2b55ae06a067","type":"WheelZoomTool"},{"attributes":{},"id":"bec11ec5-7ff1-4e00-b213-cbabe80fb173","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"E"},"id":"14d9ab0f-27e2-4d80-9235-a86c7f899695","type":"Title"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e5bb9a05-5c8e-4528-89b2-b5f079dd2192","type":"Circle"},{"attributes":{"callback":null},"id":"8ae6e950-dc47-4c85-b80a-7d8720697c55","type":"DataRange1d"},{"attributes":{},"id":"81af40bb-0ef2-43da-9525-9edc17fd085c","type":"PanTool"},{"attributes":{"source":{"id":"616cc21c-6b47-4ecf-92bb-30279ee2d6f1","type":"ColumnDataSource"}},"id":"ed286d5b-f4a3-4492-a0dd-28ac2b273cd2","type":"CDSView"},{"attributes":{},"id":"04748899-e0d2-4e57-95e2-c285335090db","type":"PanTool"},{"attributes":{},"id":"6d3d3db9-f899-4b55-ae90-b752d31c7a45","type":"BasicTickFormatter"},{"attributes":{},"id":"7df9f7c1-e7c5-4ec4-bc23-c0d14cde6e7a","type":"ResetTool"},{"attributes":{},"id":"d8d74358-e910-4676-a0bf-f5a10e019b2b","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"d3e892e2-2606-4657-9432-c7ee8cff4644","subtype":"Figure","type":"Plot"},"ticker":{"id":"33789d76-3b1c-4582-9ee8-8392ac4de6fc","type":"BasicTicker"}},"id":"685539ab-dd9b-48d5-8fce-6b147b0128fd","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b04ced03-170c-4bdc-89b2-f7fbc09bd0c9","type":"Circle"},{"attributes":{"source":{"id":"8dbe5556-fd6f-4427-a82e-d11cbb8e0758","type":"ColumnDataSource"}},"id":"72521d62-7db6-4816-8854-52eeeb84012a","type":"CDSView"},{"attributes":{"overlay":{"id":"7cf5a5b3-805d-41d1-bf82-1a549ffeb30a","type":"BoxAnnotation"}},"id":"1ba7e459-3d6d-491f-a9c7-d32343ec574e","type":"BoxZoomTool"},{"attributes":{},"id":"947fc18c-baa0-4b76-92e3-b653ca8a7222","type":"HelpTool"},{"attributes":{"axis_label":"Fluorescence (AU)","formatter":{"id":"532b18c9-5416-4b32-a26a-5b66b3a9b205","type":"BasicTickFormatter"},"plot":{"id":"d3e892e2-2606-4657-9432-c7ee8cff4644","subtype":"Figure","type":"Plot"},"ticker":{"id":"33789d76-3b1c-4582-9ee8-8392ac4de6fc","type":"BasicTicker"}},"id":"3182da9f-8c64-41a2-9973-b89e13e1cfae","type":"LinearAxis"},{"attributes":{},"id":"b168aff4-3fdf-46eb-a076-4bdd978f6595","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7cf5a5b3-805d-41d1-bf82-1a549ffeb30a","type":"BoxAnnotation"},{"attributes":{},"id":"ed454531-b2ac-4d5d-b1f1-c799411e3906","type":"LinearScale"},{"attributes":{},"id":"7b6910e5-990b-49f9-9c08-ed5dbf53e770","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_ ...

# %% [markdown]
# We can see that after photobleaching, the normalized fluorescence drops to around 0.2 to 0.3. When they recover, they all plateau around 0.9 to 1. None of them are noticeably extremely worse or extremely better at recovery, in terms of the slope (speed of recovery ~same).
#
# **b)** Now we'll try using MCMC for parameter estimation of D and k_off. We do this by first modeling each experiment as independent and assuming that the difference between our modeled normalized mean fluorescence and the experimental normalized mean fluorescence is normally distributed (central limit theorem). It doesn't matter so much whether we use uniform or Jeffreys, as sated in a number of previous homeworks. However, since don't care about $f_f$ and $f_b$ and they're proportions/fractions, we'll use a uniform distribution, while $D, k_{off}, \sigma$ will be Jeffreys, as they all affect scaling.
#
# First, we'll write a function to calculate the theoretical mean fluorescence:

# %%
def thr_fluor(t, D, k_off, ff, fb, di):
    """ Calculate the theoretical normalized fluorescence at that time """
    
    # Initialize product of psi functions
    psi = 1
    
    # Calculate psi
    for dim in di:
        psi *= ( dim / 2 * pm.math.erf(dim / tt.sqrt(4 * D * t)) - 
                 tt.sqrt(D * t / np.pi) * (1 - tt.exp(- dim ** 2 / (4 * D * t))) )
        
    # Calculate final value for I_norm(t)
    return ff * (1 - psi * fb * (4 * tt.exp(-k_off * t)) / (pm.math.prod(dim)))
               
def sample_fluor(times, norm_fluor):
    """ Sample the normalized fluorescence values and find the most common parameters """
    
    with pm.Model() as norm_model:
        # Priors
        D = bebi103.pm.Jeffreys('D', lower=1/60, upper=6)
        k_off = bebi103.pm.Jeffreys('k_off', lower=1/60, upper=6)
        sd = bebi103.pm.Jeffreys('sd', lower=1/60, upper=6)
        ff = pm.Uniform('ff', lower=0, upper=1)
        fb = pm.Uniform('fb', lower=0, upper=1)

        di = np.array([40 * RES, 40 * RES])

        # Theoretical value
        mu = thr_fluor(times, D, k_off, ff, fb, di)

        # Likelihood
        n_obs = pm.Normal('n_obs', mu=mu, sd=sd, observed=norm_fluor)
        
        # Draw samples
        trace = pm.sample(init='advi+adapt_diag', draws=10000, tune=2000, njobs=2)
        
        # Convert to data frame
        df_mcmc = bebi103.pm.trace_to_dataframe(trace, log_post=True)
        
        return df_mcmc, trace, norm_model

# %%
df = []
trace = []

for index, image in enumerate(norm_fluor):
    df_curr, trace_curr, _ = sample_fluor(times[FIRST_BLEACH:], image[FIRST_BLEACH:]) 
    df.append(df_curr)
    trace.append(trace_curr)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = -336.64:  13%|█▎        | 25199/200000 [00:39<04:26, 655.70it/s]
# Convergence archived at 25200
# Interrupted at 25,199 [12%]: Average Loss = -141.27
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = -313.49:  12%|█▏        | 24089/200000 [00:37<04:32, 645.02it/s]
# Convergence archived at 24100
# Interrupted at 24,099 [12%]: Average Loss = -120.56
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = -316.57:  12%|█▏        | 24258/200000 [00:48<08:18, 352.77it/s]
# Convergence archived at 24300
# Interrupted at 24,299 [12%]: Average Loss = -119.61
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = -332.36:  12%|█▏        | 23851/200000 [00:47<03:30, 835.08it/s]
# Convergence archived at 23900
# Interrupted at 23,899 [11%]: Average Loss = -138.38
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = -289.59:  10%|█         | 20047/200000 [00:41<05:14, 572.80it/s]
# Convergence archived at 20100
# Interrupted at 20,099 [10%]: Average Loss = -104.15
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = -329.43:  11%|█▏        | 22993/200000 [00:40<05:07, 576.36it/s]
# Convergence archived at 23000
# Interrupted at 22,999 [11%]: Average Loss = -132.82
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = -324.3:  12%|█▎         | 23950/200000 [00:48<05:33, 527.84it/s]
# Convergence archived at 24000
# Interrupted at 23,999 [11%]: Average Loss = -124.54
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = -337.3:  12%|█▎         | 23767/200000 [00:49<05:29, 535.16it/s]
# Convergence archived at 23800
# Interrupted at 23,799 [11%]: Average Loss = -143.84

# %%
def thr_fluor_np(t, D, k_off, ff, fb, di):
    """ Calculate the theoretical normalized fluorescence at that time using np """
    
    # Initialize product of psi functions
    psi = 1
    
    # Calculate psi
    for dim in di:
        psi *= ( dim / 2 * scipy.special.erf(dim / np.sqrt(4 * D * t)) - 
                 np.sqrt(D * t / np.pi) * (1 - np.exp(- dim ** 2 / (4 * D * t))) )
        
    # Calculate final value for I_norm(t)
    return ff * (1 - psi * fb * (4 * np.exp(-k_off * t)) / (np.prod(dim)))

plots = []
tot_vals = np.array([])

mean = []
sd = []

for index, image in enumerate(df):
    
    # Get the index of the most probable parameter set
    max_ind = image['log_posterior'].idxmax()

    D, ff, fb, k_off = image.loc[max_ind, ['D', 'ff', 'fb', 'k_off']]
    
    # Get the means
    mean.append((D, k_off))
    
    # Get the standard deviations
    sd.append((pm.stats.mc_error(image['D']), pm.stats.mc_error(image['k_off'])))
    
    if index == 0:
        tot_vals = image[['D', 'ff', 'fb', 'k_off']].values
        
    else:
        tot_vals = np.append(tot_vals, image[['D', 'ff', 'fb', 'k_off']].values, axis=0)
    
    print("""
          Image {0:s}:
          ---------
          D = {1:.3f}, ff = {2:.3f}, fb = {3:.3f}, k_off = {4:.3f}
          """.format(names[index], D, ff, fb, k_off))

    p = bokeh.plotting.figure(width=500,
                              height=400,
                              x_axis_label='Time (s)',
                              y_axis_label='Normalized mean fluorescence',
                              title=names[index])

    p.line(times[FIRST_BLEACH:], thr_fluor_np(times[FIRST_BLEACH:], D, k_off, ff, fb, np.array([40 * RES, 40 * RES])))

    p.circle(times[FIRST_BLEACH-1:], norm_fluor[index][FIRST_BLEACH-1:])
    
    plots.append(p)

bokeh.io.show(bokeh.layouts.gridplot(plots, ncols=2))
# Out:
#           Image A:
#           ---------
#           D = 0.876, ff = 0.938, fb = 0.142, k_off = 0.176
#
#
#           Image B:
#           ---------
#           D = 1.381, ff = 0.979, fb = 0.148, k_off = 0.064
#
#
#           Image C:
#           ---------
#           D = 0.979, ff = 0.978, fb = 0.146, k_off = 0.116
#
#
#           Image D:
#           ---------
#           D = 1.064, ff = 0.918, fb = 0.142, k_off = 0.189
#
#
#           Image E:
#           ---------
#           D = 0.426, ff = 0.905, fb = 0.134, k_off = 0.209
#
#
#           Image F:
#           ---------
#           D = 0.514, ff = 0.914, fb = 0.135, k_off = 0.245
#
#
#           Image G:
#           ---------
#           D = 0.887, ff = 0.957, fb = 0.136, k_off = 0.150
#
#
#           Image H:
#           ---------
#           D = 0.223, ff = 0.900, fb = 0.128, k_off = 0.342
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3cafe797-7a46-4525-b67e-f077cd5ae61c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("3cafe797-7a46-4525-b67e-f077cd5ae61c");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3cafe797-7a46-4525-b67e-f077cd5ae61c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3cafe797-7a46-4525-b67e-f077cd5ae61c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"18e7f257-6fa2-4da3-af72-a4b915298aab":{"roots":{"references":[{"attributes":{"callback":null},"id":"b3cdf782-a78d-4a9c-b3f4-411f8fa5243c","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d402a449-609a-45b3-9344-9855458cd2ed","type":"Line"},{"attributes":{"axis_label":"Normalized mean fluorescence","formatter":{"id":"a5052d40-669d-4813-a8bc-3df9d33843a7","type":"BasicTickFormatter"},"plot":{"id":"9d597cb5-13c5-4eca-9dde-d0256525bab1","subtype":"Figure","type":"Plot"},"ticker":{"id":"67efa2c9-c154-44d2-aed4-40addb9e58b4","type":"BasicTicker"}},"id":"3eff79ad-ec51-4eea-a641-1b9fffcbb858","type":"LinearAxis"},{"attributes":{"plot":null,"text":"F"},"id":"70752884-c382-4acf-8c5b-c32a1220bf6c","type":"Title"},{"attributes":{},"id":"1596fb13-fb65-4984-9ad2-83e69b5f4a5b","type":"BasicTicker"},{"attributes":{},"id":"83559a59-0479-400a-97d5-34b416ff5f86","type":"LinearScale"},{"attributes":{},"id":"618ba301-b332-464f-881e-00938851abce","type":"LinearScale"},{"attributes":{},"id":"b7290ce4-340f-4955-ae64-2aae55460a33","type":"BasicTicker"},{"attributes":{"plot":{"id":"9d597cb5-13c5-4eca-9dde-d0256525bab1","subtype":"Figure","type":"Plot"},"ticker":{"id":"b7290ce4-340f-4955-ae64-2aae55460a33","type":"BasicTicker"}},"id":"7852bcab-4f91-48b7-bf26-84af5fa155e5","type":"Grid"},{"attributes":{"data_source":{"id":"34b3e608-f3d4-41ec-a192-454264119316","type":"ColumnDataSource"},"glyph":{"id":"d0c8b2a4-7922-4c16-be4b-030a71541f3a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e745fe0a-4e48-4376-9d97-6adafb326f8e","type":"Circle"},"selection_glyph":null,"view":{"id":"39210932-4e8d-4720-af80-b25e590b6a14","type":"CDSView"}},"id":"88f17542-f51b-4acf-b1e6-f0744cbf6296","type":"GlyphRenderer"},{"attributes":{"source":{"id":"2fd98bfa-3912-4f35-a382-55c151af6687","type":"ColumnDataSource"}},"id":"4a77595e-0de7-4ada-adcb-7c04bd1a6644","type":"CDSView"},{"attributes":{"plot":null,"text":"A"},"id":"9852030b-003f-4fce-beef-4ee144a41934","type":"Title"},{"attributes":{"plot":null,"text":"C"},"id":"ee43e8a8-e06f-41ed-806e-527e29b2b66a","type":"Title"},{"attributes":{"callback":null},"id":"7f0e0e86-735b-4a6a-9dde-8ef5b9a772c2","type":"DataRange1d"},{"attributes":{"axis_label":"Time (s)","formatter":{"id":"fab9c924-c13d-44ca-8fad-7c5f7b23d913","type":"BasicTickFormatter"},"plot":{"id":"aeff2568-b7de-434e-80a0-8dade5bdc43e","subtype":"Figure","type":"Plot"},"ticker":{"id":"1261d7ad-7ff1-4e25-8959-5bb71dfe1ef6","type":"BasicTicker"}},"id":"e4036fa1-189f-4d1b-b96c-b5050578b8ab","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[128]},"y":{"__ndarray__":"...","dtype":"float64","shape":[128]}}},"id":"2fd98bfa-3912-4f35-a382-55c151af6687","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"9f7276bc-6398-46ba-a1a7-d5cd0f379109","subtype":"Figure","type":"Plot"},"ticker":{"id":"1596fb13-fb65-4984-9ad2-83e69b5f4a5b","type":"BasicTicker"}},"id":"b87551b1-49a3-4e89-af35-16fe98f6f124","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"607c9936-e0bc-48bb-acd9-970838e76a0b","type":"Line"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"83bda144-b5cb-4cff-8f82-9e86e26a7431","type":"PanTool"},{"id":"28dd7527-cf78-4a59-ab3f-a34c5b75b9cc","type":"WheelZoomTool"},{"id":"4eab5228-8cc4-428e-94d2-a1137026e462","type":"BoxZoomTool"},{"id":"c476bba3-255b-44e6-bb37-2eb1668dd1c1","type":"SaveTool"},{"id":"e658e818-4f3e-4f93-b524-81fa52eb1eeb","type":"ResetTool"},{"id":"e6b7f58e-3345-49f0-af92-6a197ba0971a","type":"HelpTool"}]},"id":"62189abc-08ab-4cb2-bcfa-3559c9b8cae5","type":"Toolbar"},{"attributes":{},"id":"ea5492b2-96cb-4c1c-ba2e-1c1b26403bec","type":"WheelZoomTool"},{"attributes":{"axis_label":"Time (s)","formatter":{"id":"6bfa6ef2-3d17-4501 ...

# %% [markdown]
# We can see from the above plots that all of the experiments yield a result similar to that predicted by the model. As a result, we can probably treat the data as independent samples and propagate error by assuming a Gaussian distribution for the independent samples and using error propagation derived in problem 3.1:

# %%
sigma_D = 1 / np.sum([1 / sig[0]**2 for sig in sd])
sigma_k = 1 / np.sum([1 / sig[1]**2 for sig in sd])

mu_D = sigma_D * np.sum([mean[i][0] / sd[i][0]**2 for i in range(len(mean))])
mu_k = sigma_k * np.sum([mean[i][1] / sd[i][1]**2 for i in range(len(mean))])

# %% [markdown]
# Printing our result:

# %%
print("""
      D = {0:.3f} ± {1:.3f}
      K = {2:.3f} ± {3:.3f}""".format(mu_D, sigma_D, mu_k, sigma_k))
# Out:
#       D = 0.772 ± 0.000
#       K = 0.167 ± 0.000

# %% [markdown]
# Therefore, our final preducted median value of $D$ is 0.772, and $k_{off}$ is 0.167. Comparing the $D$ values to the paper, it looks on the low end, but this might change due to method and how we defined our ROIs, a testament to different conclusions based on small changes in data analysis! However, just from our plot, we can see that the fit does seem appropriate for the data, and the total standard deviation of the two were on the order of 10e-6.
